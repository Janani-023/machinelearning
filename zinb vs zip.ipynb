# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.count_model import (
    ZeroInflatedPoisson,
    ZeroInflatedNegativeBinomialP
)

# -----------------------------
# 1. Generate Synthetic Data
# -----------------------------
np.random.seed(42)

n = 1000

# Independent variable
x = np.random.normal(0, 1, n)

# Probability of extra zeros
p_zero = 1 / (1 + np.exp(-(-1 + 2 * x)))

# Mean for count model
mu = np.exp(1 + 0.5 * x)

# Generate Negative Binomial counts
counts = np.random.negative_binomial(n=1, p=1 / (1 + mu))

# Add extra zeros
y = np.where(np.random.rand(n) < p_zero, 0, counts)

# Create dataframe
df = pd.DataFrame({
    'x': x,
    'y': y
})

# -----------------------------
# 2. Check Zero Percentage
# -----------------------------
zero_percent = (df['y'] == 0).mean() * 100
print(f"Percentage of zeros: {zero_percent:.2f}%")

# -----------------------------
# 3. Prepare Input Matrix
# -----------------------------
X = sm.add_constant(df['x'])

# -----------------------------
# 4. Fit ZIP Model
# -----------------------------
zip_model = ZeroInflatedPoisson(
    endog=df['y'],
    exog=X,
    exog_infl=X,
    inflation='logit'
)

zip_result = zip_model.fit()

# -----------------------------
# 5. Fit ZINB Model
# -----------------------------
zinb_model = ZeroInflatedNegativeBinomialP(
    endog=df['y'],
    exog=X,
    exog_infl=X,
    inflation='logit'
)

zinb_result = zinb_model.fit()

# -----------------------------
# 6. Show Results
# -----------------------------
print("\n===== Zero Inflated Poisson (ZIP) =====")
print(zip_result.summary())

print("\n===== Zero Inflated Negative Binomial (ZINB) =====")
print(zinb_result.summary())

# -----------------------------
# 7. Compare AIC
# -----------------------------
print("\n===== Model Comparison =====")
print(f"ZIP AIC  : {zip_result.aic:.2f}")
print(f"ZINB AIC : {zinb_result.aic:.2f}")

if zinb_result.aic < zip_result.aic:
    print("✅ ZINB is better because it handles both excess zeros and overdispersion.")
else:
    print("✅ ZIP is better for this dataset.")
# Out:
# Percentage of zeros: 55.70%
# Optimization terminated successfully.
#          Current function value: 1.626364
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1.501435
#          Iterations: 26
#          Function evaluations: 27
#          Gradient evaluations: 27
#
# ===== Zero Inflated Poisson (ZIP) =====
#                      ZeroInflatedPoisson Regression Results
# ...
# Dep. Variable:                       y   No. Observations:                 1000
# Model:             ZeroInflatedPoisson   Df Residuals:                      998
# Method:                            MLE   Df Model:                            1
# Date:                 Sun, 12 Apr 2026   Pseudo R-squ.:                 0.06578
# Time:                         17:08:49   Log-Likelihood:                -1626.4
# converged:                        True   LL-Null:                       -1740.9
# ...

# %%
from statsmodels.discrete.count_model import ZeroInflatedNegativeBinomialP

model_zinb = ZeroInflatedNegativeBinomialP(
    endog=data['y'],
    exog=data[['x1', 'x2']],
    exog_infl=data[['x1', 'x2']],  # logistic part
    inflation='logit'
)

result_zinb = model_zinb.fit()
print(result_zinb.summary())

# %%
x
# Out:
# array([ 4.96714153e-01, -1.38264301e-01,  6.47688538e-01,  1.52302986e+00,
#        -2.34153375e-01, -2.34136957e-01,  1.57921282e+00,  7.67434729e-01,
#        -4.69474386e-01,  5.42560044e-01, -4.63417693e-01, -4.65729754e-01,
#         2.41962272e-01, -1.91328024e+00, -1.72491783e+00, -5.62287529e-01,
#        -1.01283112e+00,  3.14247333e-01, -9.08024076e-01, -1.41230370e+00,
#         1.46564877e+00, -2.25776300e-01,  6.75282047e-02, -1.42474819e+00,
#        -5.44382725e-01,  1.10922590e-01, -1.15099358e+00,  3.75698018e-01,
#        -6.00638690e-01, -2.91693750e-01, -6.01706612e-01,  1.85227818e+00,
#        -1.34972247e-02, -1.05771093e+00,  8.22544912e-01, -1.22084365e+00,
#         2.08863595e-01, -1.95967012e+00, -1.32818605e+00,  1.96861236e-01,
#         7.38466580e-01,  1.71368281e-01, -1.15648282e-01, -3.01103696e-01,
#        -1.47852199e+00, -7.19844208e-01, -4.60638771e-01,  1.05712223e+00,
# ...

# %%
df
# Out:
#             x  y
# 0    0.496714  0
# 1   -0.138264  1
# 2    0.647689  0
# 3    1.523030  0
# 4   -0.234153  6
# ..        ... ..
# 995 -0.281100  0
# 996  1.797687  0
# 997  0.640843  0
# 998 -0.571179  2
# 999  0.572583  7
#
# [1000 rows x 2 columns]
